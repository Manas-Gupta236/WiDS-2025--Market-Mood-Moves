# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Manas\anaconda3\envs\market_mood\python.exe

# %%
import yfinance as yf

def download_stock_data(ticker="AAPL", start="2024-01-01", end="2024-12-31"):
    """
    Downloads historical OHLC stock data using yfinance
    """
    data = yf.download(ticker, start=start, end=end)
    return data

if __name__ == "__main__":
    df = download_stock_data()
    print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  183.903229  186.677036  182.169601  185.399096  82488700
# 2024-01-03  182.526230  184.140985  181.713894  182.496512  58414500
# 2024-01-04  180.208115  181.377068  179.187752  180.445860  71983600
# 2024-01-05  179.484955  181.050175  178.484409  180.287390  62379700
# 2024-01-08  183.823975  183.863609  179.801961  180.386437  59144500

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Manas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

def preprocess_text(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words("english"))
    filtered = [w.lower() for w in tokens if w.isalpha() and w.lower() not in stop_words]

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w) for w in filtered]

    return lemmatized

if __name__ == "__main__":
    sample = "Apple stock surges 5% on strong earnings!"
    print(preprocess_text(sample))
# Out:
# ['apple', 'stock', 'surge', 'strong', 'earnings']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Manas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Manas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Manas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download("vader_lexicon")

def vader_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    return sia.polarity_scores(text)

if __name__ == "__main__":
    text = "Apple stock surges on strong earnings!"
    print(vader_sentiment(text))
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Manas\AppData\Roaming\nltk_data...
# {'neg': 0.0, 'neu': 0.582, 'pos': 0.418, 'compound': 0.5562}

# %%
import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForSequenceClassification

tokenizer = BertTokenizer.from_pretrained("ProsusAI/finbert")
model = BertForSequenceClassification.from_pretrained("ProsusAI/finbert")

def finbert_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)

    with torch.no_grad():
        outputs = model(**inputs)

    probs = F.softmax(outputs.logits, dim=1)
    return {
        "positive": probs[0][0].item(),
        "negative": probs[0][1].item(),
        "neutral": probs[0][2].item(),
    }

if __name__ == "__main__":
    sample = "The company reported a decline in quarterly profits."
    print(finbert_sentiment(sample))
# Out:
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# C:\Users\Manas\anaconda3\envs\market_mood\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Manas\.cache\huggingface\hub\models--ProsusAI--finbert. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt: 0.00B [00:00, ?B/s]
# ...

# %%
def chunk_text(text, max_words=200):
    words = text.split()
    chunks = []

    for i in range(0, len(words), max_words):
        chunk = " ".join(words[i:i+max_words])
        chunks.append(chunk)

    return chunks

if __name__ == "__main__":
    long_text = "Apple announced results " * 300
    print(len(chunk_text(long_text)))
# Out:
# 5

# %%
import yfinance as yf
import numpy as np
from statsmodels.tsa.stattools import adfuller

def adf_test():
    data = yf.download("AAPL", start="2023-01-01", end="2024-01-01")
    returns = np.log(data["Close"] / data["Close"].shift(1)).dropna()

    result = adfuller(returns)
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])

if __name__ == "__main__":
    adf_test()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ADF Statistic: -14.840393365907877
# p-value: 1.8409139807903505e-27
